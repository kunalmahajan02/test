# %%
import cv2

# %%
import matplotlib.pyplot as mpl

# %%
config_file = 'ssd_mobilenet_v3_large_coco_2020_01_14.pbtxt'

# %%
frozen_model = 'frozen_inference_graph.pb'

# %%
model = cv2.dnn_DetectionModel(frozen_model,config_file)

# %%
classLabels = []
file_name = 'labels.txt'
with open(file_name,'rt') as fpt:
    classLabels = fpt.read().rstrip('\n').split('\n')

# %%
print(classLabels)
# Out:
# ['person', 'bicycle', 'car', 'motorbike', 'aeroplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'sofa', 'pottedplant', 'bed', 'diningtable', 'toilet', 'tvmonitor', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

# %%
model.setInputSize(320,320)
model.setInputScale(1.0/127.5)
model.setInputMean((127.5,127.5,127.5))
model.setInputSwapRB(True)
# Out:
# <dnn_Model 0000022566D281F0>

# %%
img = cv2.imread('car1.jpg')

# %%
ClassIndex , confidece ,bbox = model.detect(img,confThreshold=0.5)

# %%
print(bbox)
# Out:
# [[ 71 165 502 266]
#  [ 67 155 503 279]]

# %%
font_scale = 3
font = cv2.FONT_HERSHEY_PLAIN
for ClassInd , conf , boxes in zip(ClassIndex.flatten(),confidece.flatten(),bbox):
    cv2.rectangle(img,boxes,(255,0,0),2)
    cv2.putText(img,classLabels[ClassInd-1],(boxes[0]+10,boxes[1]+40),font,fontScale=font_scale,color=(0,255,0),thickness=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\KUNALM~1\AppData\Local\Temp/ipykernel_36460/1962347759.py in <module>
#       1 font_scale = 3
#       2 font = cv2.FONT_HERSHEY_PLAIN
# ----> 3 if(ClassIndex==3):
#       4     for ClassInd , conf , boxes in zip(ClassIndex.flatten(),confidece.flatten(),bbox):
#       5         cv2.rectangle(img,boxes,(255,0,0),2)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
mpl.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
print(boxes)
# Out:
# [ 67 155 503 279]

# %%
print(conf)
# Out:
# 0.5740461

# %%
img2 = cv2.imread('car2.jpg')

# %%
ClassIndex2 , confidece2 , bbox2  = model.detect(img2,confThreshold= 0.5)

# %%
print(ClassIndex2)
# Out:
# [3]

# %%
print(bbox2)
# Out:
# [[ 36 107 448 256]]

# %%
font_scale = 3
font = cv2.FONT_HERSHEY_PLAIN
if(ClassIndex2==3):
    for ClassInd , conf , boxes in zip(ClassIndex2.flatten(),confidece2.flatten(),bbox2):
        cv2.rectangle(img2,boxes,(255,0,0),2)
        cv2.putText(img2,classLabels[ClassInd-1],(boxes[0]+10,boxes[1]+40),font,fontScale=font_scale,color=(0,255,0),thickness=3)

# %%
mpl.imshow(cv2.cvtColor(img2,cv2.COLOR_BGR2RGB))

# %%
areaofcar1 = (bbox[0][2]-bbox[0][0])*(bbox[0][3]-bbox[0][1])

# %%
areaofcar2 = (bbox2[0][2]-bbox2[0][0])*(bbox2[0][3]-bbox2[0][1])

# %%
if (areaofcar2 > areaofcar1):
    print("car is coming")
else:
    print("Car is going")
# Out:
# car is coming

# %%
print(areaofcar1)
# Out:
# 43531

# %%
print(areaofcar2)
# Out:
# 61388
